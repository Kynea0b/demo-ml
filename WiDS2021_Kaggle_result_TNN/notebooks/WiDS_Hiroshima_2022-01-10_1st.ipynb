# %%
# 共通事前処理

# 余分なワーニングを非表示にする
import warnings
warnings.filterwarnings('ignore')

# 必要ライブラリのimport
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# matplotlib日本語化対応
import japanize_matplotlib

# データフレーム表示用関数
from IPython.display import display

# 表示オプション調整
# numpyの浮動小数点の表示精度
np.set_printoptions(suppress=True, precision=4)

# pandasでの浮動小数点の表示精度
pd.options.display.float_format = '{:.4f}'.format

# データフレームですべての項目を表示
pd.set_option("display.max_columns",None)

# グラフのデフォルトフォント指定
plt.rcParams["font.size"] = 14

# 乱数の種
random_seed = 123

# %%
df = pd.read_csv('../input/sales.csv')

# %%
df
# Out:
#           NO     売上伝票日付  直送指定  委託区分  見積番号   得意先コード     得意先名  発送先コード  発送先名  \
# 0          1   2017/3/1     0     0   NaN  ｗH-2501     ㈱HBC     NaN   NaN
# 1          2   2017/3/1     0     0   NaN  ｗH-2501     ㈱HBC     NaN   NaN
# 2          3   2017/3/1     0     0   NaN  ｗH-2501     ㈱HBC     NaN   NaN
# 3          4   2017/3/1     0     0   NaN  ｗH-2501     ㈱HBC     NaN   NaN
# 4          5   2017/3/1     0     0   NaN  ｗH-2501     ㈱HBC     NaN   NaN
# ...      ...        ...   ...   ...   ...      ...      ...     ...   ...
# 16629  16630  2021/1/30     0     0   NaN  ｗH-3001  酒原酒造(株)     NaN   NaN
# 16630  16631  2021/1/30     0     0   NaN  ｗH-3001  酒原酒造(株)     NaN   NaN
# 16631  16632  2021/1/30     0     0   NaN  ｗH-3001  酒原酒造(株)     NaN   NaN
# 16632  16633  2021/1/30     0     0   NaN  ｗH-3001  酒原酒造(株)     NaN   NaN
# 16633  16634  2021/1/30     0     0   NaN  ｗH-3001  酒原酒造(株)     NaN   NaN
#
#        自社担当者コード 請求得意先コード   得意先名_1  随時請求区分      請求予定日     請求書発行日  請求書発行済み  \
# 0           NaN  ｗH-2501     ㈱HBC       0  2017/3/31  2017/3/31        0
# 1           NaN  ｗH-2501     ㈱HBC       0  2017/3/31  2017/3/31        0
# 2           NaN  ｗH-2501     ㈱HBC       0  2017/3/31  2017/3/31        0
# 3           NaN  ｗH-2501     ㈱HBC       0  2017/3/31  2017/3/31        0
# 4           NaN  ｗH-2501     ㈱HBC       0  2017/3/31  2017/3/31        0
# ...         ...      ...      ...     ...        ...        ...      ...
# 16629       NaN  ｗH-3001  酒原酒造(株)       0  2021/1/31  2021/1/31        1
# 16630       NaN  ｗH-3001  酒原酒造(株)       0  2021/1/31  2021/1/31        1
# 16631       NaN  ｗH-3001  酒原酒造(株)       0  2021/1/31  2021/1/31        1
# 16632       NaN  ｗH-3001  酒原酒造(株)       0  2021/1/31  2021/1/31        1
# 16633       NaN  ｗH-3001  酒原酒造(株)       0  2021/1/31  2021/1/31        1
#
#        請求先送月数      回収日締切      発送予定日  広告企画区分    商品コード      数量   単価     金額
# 0           0  2017/4/30  2017/4/27     NaN  W102005  8.0000  344  2,735
# 1           0  2017/4/30  2017/4/27     NaN  W102027  6.0000  204  1,317
# 2           0  2017/4/30  2017/4/27     NaN  W102029 10.0000  177  1,720
# 3           0  2017/4/30  2017/4/27     NaN  W102040  6.0000  186  1,058
# 4           0  2017/4/30  2017/4/27     NaN  W102041  4.0000  212    943
# ...       ...        ...        ...     ...      ...     ...  ...    ...
# 16629       0        NaN  2021/1/30     NaN  W102005  5.0000  474  2,371
# 16630       0        NaN  2021/1/30     NaN  W102027  5.0000  278  1,388
# 16631       0        NaN  2021/1/30     NaN  W102040  6.0000  253  1,519
# 16632       0        NaN  2021/1/30     NaN  W102027  6.0000  278  1,665
# 16633       0        NaN  2021/1/30     NaN  W102042  6.0000  287  1,722
#
# [16634 rows x 24 columns]

# %%
print(df.dtypes)
# Out:
# NO            int64
# 売上伝票日付       object
# 直送指定          int64
# 委託区分          int64
# 見積番号        float64
# 得意先コード       object
# 得意先名         object
# 発送先コード      float64
# 発送先名        float64
# 自社担当者コード    float64
# 請求得意先コード     object
# 得意先名_1       object
# 随時請求区分        int64
# 請求予定日        object
# 請求書発行日       object
# 請求書発行済み       int64
# 請求先送月数        int64
# 回収日締切        object
# 発送予定日        object
# 広告企画区分      float64
# 商品コード        object
# 数量          float64
# 単価           object
# 金額           object
# dtype: object

# %%
df2 = df[['売上伝票日付', '金額']]

# %%
df2
# Out:
#           売上伝票日付     金額
# 0       2017/3/1  2,735
# 1       2017/3/1  1,317
# 2       2017/3/1  1,720
# 3       2017/3/1  1,058
# 4       2017/3/1    943
# ...          ...    ...
# 16629  2021/1/30  2,371
# 16630  2021/1/30  1,388
# 16631  2021/1/30  1,519
# 16632  2021/1/30  1,665
# 16633  2021/1/30  1,722
#
# [16634 rows x 2 columns]

# %%
df3 = df2.groupby(['売上伝票日付']).sum()

# %%
df3
# Out:
#                                                            金額
# 売上伝票日付
# 2017/10/1                                1,1052,2101,3261,326
# 2017/10/10  1,3291,1051,7802,6961,5301,7682,8801,3261,3261...
# 2017/10/11  1,329-624-2734,5452,2901,7201,9401,9408403,560...
# 2017/10/12  6481,1051,1051,1452,6961,5901,5527,7357,7351,7...
# 2017/10/13  4,5454,5453,4401,3482,9102,6501,0701,7688,8401...
# ...                                                       ...
# 2021/1/4      1,2662,8701,4441,3884,7418618331,1551,266862724
# 2021/1/5    2,0741,2141,2571,0561,1081,2631,0054,9091,5053...
# 2021/1/7    1,6599711,2578451,1081,2637531,2662,8701,4441,...
# 2021/1/8                   8627248618668618331,1551,266862724
# 2021/1/9    2,9047291,0051,0564437581,0051,2662,3711,3881,...
#
# [1116 rows x 1 columns]

# %%
pd.read_csv?

# %%
df = pd.read_csv('../input/sales.csv', thousands=',', parse_dates=[1])

# %%
df
# Out:
#           NO     売上伝票日付  直送指定  委託区分  見積番号   得意先コード     得意先名  発送先コード  発送先名  \
# 0          1 2017-03-01     0     0   NaN  ｗH-2501     ㈱HBC     NaN   NaN
# 1          2 2017-03-01     0     0   NaN  ｗH-2501     ㈱HBC     NaN   NaN
# 2          3 2017-03-01     0     0   NaN  ｗH-2501     ㈱HBC     NaN   NaN
# 3          4 2017-03-01     0     0   NaN  ｗH-2501     ㈱HBC     NaN   NaN
# 4          5 2017-03-01     0     0   NaN  ｗH-2501     ㈱HBC     NaN   NaN
# ...      ...        ...   ...   ...   ...      ...      ...     ...   ...
# 16629  16630 2021-01-30     0     0   NaN  ｗH-3001  酒原酒造(株)     NaN   NaN
# 16630  16631 2021-01-30     0     0   NaN  ｗH-3001  酒原酒造(株)     NaN   NaN
# 16631  16632 2021-01-30     0     0   NaN  ｗH-3001  酒原酒造(株)     NaN   NaN
# 16632  16633 2021-01-30     0     0   NaN  ｗH-3001  酒原酒造(株)     NaN   NaN
# 16633  16634 2021-01-30     0     0   NaN  ｗH-3001  酒原酒造(株)     NaN   NaN
#
#        自社担当者コード 請求得意先コード   得意先名_1  随時請求区分      請求予定日     請求書発行日  請求書発行済み  \
# 0           NaN  ｗH-2501     ㈱HBC       0  2017/3/31  2017/3/31        0
# 1           NaN  ｗH-2501     ㈱HBC       0  2017/3/31  2017/3/31        0
# 2           NaN  ｗH-2501     ㈱HBC       0  2017/3/31  2017/3/31        0
# 3           NaN  ｗH-2501     ㈱HBC       0  2017/3/31  2017/3/31        0
# 4           NaN  ｗH-2501     ㈱HBC       0  2017/3/31  2017/3/31        0
# ...         ...      ...      ...     ...        ...        ...      ...
# 16629       NaN  ｗH-3001  酒原酒造(株)       0  2021/1/31  2021/1/31        1
# 16630       NaN  ｗH-3001  酒原酒造(株)       0  2021/1/31  2021/1/31        1
# 16631       NaN  ｗH-3001  酒原酒造(株)       0  2021/1/31  2021/1/31        1
# 16632       NaN  ｗH-3001  酒原酒造(株)       0  2021/1/31  2021/1/31        1
# 16633       NaN  ｗH-3001  酒原酒造(株)       0  2021/1/31  2021/1/31        1
#
#        請求先送月数      回収日締切      発送予定日  広告企画区分    商品コード      数量   単価    金額
# 0           0  2017/4/30  2017/4/27     NaN  W102005  8.0000  344  2735
# 1           0  2017/4/30  2017/4/27     NaN  W102027  6.0000  204  1317
# 2           0  2017/4/30  2017/4/27     NaN  W102029 10.0000  177  1720
# 3           0  2017/4/30  2017/4/27     NaN  W102040  6.0000  186  1058
# 4           0  2017/4/30  2017/4/27     NaN  W102041  4.0000  212   943
# ...       ...        ...        ...     ...      ...     ...  ...   ...
# 16629       0        NaN  2021/1/30     NaN  W102005  5.0000  474  2371
# 16630       0        NaN  2021/1/30     NaN  W102027  5.0000  278  1388
# 16631       0        NaN  2021/1/30     NaN  W102040  6.0000  253  1519
# 16632       0        NaN  2021/1/30     NaN  W102027  6.0000  278  1665
# 16633       0        NaN  2021/1/30     NaN  W102042  6.0000  287  1722
#
# [16634 rows x 24 columns]

# %%
print(df.dtypes)
# Out:
# NO                   int64
# 売上伝票日付      datetime64[ns]
# 直送指定                 int64
# 委託区分                 int64
# 見積番号               float64
# 得意先コード              object
# 得意先名                object
# 発送先コード             float64
# 発送先名               float64
# 自社担当者コード           float64
# 請求得意先コード            object
# 得意先名_1              object
# 随時請求区分               int64
# 請求予定日               object
# 請求書発行日              object
# 請求書発行済み              int64
# 請求先送月数               int64
# 回収日締切               object
# 発送予定日               object
# 広告企画区分             float64
# 商品コード               object
# 数量                 float64
# 単価                   int64
# 金額                   int64
# dtype: object

# %%
df2 = df[['売上伝票日付', '金額']]

# %%
df2
# Out:
#           売上伝票日付    金額
# 0     2017-03-01  2735
# 1     2017-03-01  1317
# 2     2017-03-01  1720
# 3     2017-03-01  1058
# 4     2017-03-01   943
# ...          ...   ...
# 16629 2021-01-30  2371
# 16630 2021-01-30  1388
# 16631 2021-01-30  1519
# 16632 2021-01-30  1665
# 16633 2021-01-30  1722
#
# [16634 rows x 2 columns]

# %%
df2.dtypes
# Out:
# 売上伝票日付    datetime64[ns]
# 金額                 int64
# dtype: object

# %%
df3 = df2.groupby(['売上伝票日付']).sum()

# %%
df3
# Out:
#                金額
# 売上伝票日付
# 2017-03-01   8213
# 2017-03-02   4307
# 2017-03-03  19571
# 2017-03-04  14965
# 2017-03-05  17022
# ...           ...
# 2021-01-25  41993
# 2021-01-26  24036
# 2021-01-28  27323
# 2021-01-29  17977
# 2021-01-30  21659
#
# [1116 rows x 1 columns]

# %%
# 欠損値チェック
df3.isnull().sum()
# Out:
# 金額    0
# dtype: int64

# %%
df3.dtypes
# Out:
# 金額    int64
# dtype: object

# %%
df3 = pd.DataFrame(df3.reset_index())

# %%
df3.dtypes
# Out:
# 売上伝票日付    datetime64[ns]
# 金額                 int64
# dtype: object

# %%
# 時系列グラフの描画 (売上金額)
plt.figure(figsize=(18,4))

# グラフ描画
plt.plot(df3['売上伝票日付'], df3['金額'], c='b')

# 方眼表示など
plt.grid()
plt.title('金額')

# 画面出力
plt.show()

# %%
df3.tail()
# Out:
#          売上伝票日付     金額
# 1111 2021-01-25  41993
# 1112 2021-01-26  24036
# 1113 2021-01-28  27323
# 1114 2021-01-29  17977
# 1115 2021-01-30  21659

# %%
import datetime as dt

# %%
df4 = df3[(dt.datetime(2019,2,1) <= df3['売上伝票日付']) & (df3['売上伝票日付'] < dt.datetime(2019,3,1))]

# %%
df5 = df3[(dt.datetime(2020,2,1) <= df3['売上伝票日付']) & (df3['売上伝票日付'] < dt.datetime(2020,3,1))]

# %%
# 時系列グラフの描画 (売上金額)
plt.figure(figsize=(18,4))

# グラフ描画
plt.plot(df4['売上伝票日付'], df4['金額'], c='b')

# 方眼表示など
plt.grid()
plt.title('金額')

# 画面出力
plt.show()

# %%
# 時系列グラフの描画 (売上金額)
plt.figure(figsize=(18,4))

# グラフ描画
plt.plot(df5['売上伝票日付'], df5['金額'], c='b')

# 方眼表示など
plt.grid()
plt.title('金額')

# 画面出力
plt.show()

# %%
df4
# Out:
#         売上伝票日付     金額
# 590 2019-02-01  12419
# 591 2019-02-02  28922
# 592 2019-02-04  10856
# 593 2019-02-05  28199
# 594 2019-02-07  11180
# 595 2019-02-08  12335
# 596 2019-02-09  27887
# 597 2019-02-10  76403
# 598 2019-02-11  27896
# 599 2019-02-12  32493
# 600 2019-02-14  24614
# 601 2019-02-15   9847
# 602 2019-02-16  27510
# 603 2019-02-18  21184
# 604 2019-02-19  24745
# 605 2019-02-21  19455
# 606 2019-02-22  20595
# 607 2019-02-23  30940
# 608 2019-02-25  20508
# 609 2019-02-26  36817
# 610 2019-02-28  53071

# %%
df5
# Out:
#         売上伝票日付     金額
# 870 2020-02-01  31951
# 871 2020-02-03  31182
# 872 2020-02-04  27446
# 873 2020-02-06  11936
# 874 2020-02-07  23074
# 875 2020-02-08  31578
# 876 2020-02-10  33031
# 877 2020-02-11  36713
# 878 2020-02-13  71822
# 879 2020-02-14  17769
# 880 2020-02-15  36225
# 881 2020-02-17  21673
# 882 2020-02-18  21885
# 883 2020-02-20  10661
# 884 2020-02-21  20627
# 885 2020-02-22  45361
# 886 2020-02-24  20790
# 887 2020-02-25  35877
# 888 2020-02-27   3549
# 889 2020-02-28  12052
# 890 2020-02-29  36123

# %%
df4.sum()
# Out:
# 金額    557876
# dtype: int64

# %%
df5.sum()
# Out:
# 金額    581325
# dtype: int64

# %%
# df4 = df3[(dt.datetime(2019,2,1) <= df3['売上伝票日付']) & (df3['売上伝票日付'] < dt.datetime(2019,3,1))]
df4 = df3[(dt.datetime(2019,1,1) <= df3['売上伝票日付']) & (df3['売上伝票日付'] < dt.datetime(2020,1,1))]

# %%
# df5 = df3[(dt.datetime(2020,2,1) <= df3['売上伝票日付']) & (df3['売上伝票日付'] < dt.datetime(2020,3,1))]
df5 = df3[(dt.datetime(2020,1,1) <= df3['売上伝票日付']) & (df3['売上伝票日付'] < dt.datetime(2021,1,1))]

# %%
for year in [2017, 2018, 2019, 2020, 2021]:
    df4 = df3[(dt.datetime(year,1,1) <= df3['売上伝票日付']) & (df3['売上伝票日付'] < dt.datetime(year+1,1,1))]
    
    fig = plt.figure(figsize=(18,4))
    ax = fig.add_subplot(111)
    ax.set_title('金額')
    ax.set_xlim(dt.datetime(year,1,1), dt.datetime(year+1,1,1))
    ax.set_ylim(0, 600000)
    ax.plot(df4['売上伝票日付'], df4['金額'], c='b')
    ax.grid()
    plt.show()

# %%
df3[(dt.datetime(2019,1,1) <= df3['売上伝票日付']) & (df3['売上伝票日付'] < dt.datetime(2019,2,1))].sum()
# Out:
# 金額    653267
# dtype: int64

# %%
for year in [2019, 2020, 2021]:
    start = dt.datetime(year-1, 11, 1)
    end = dt.datetime(year, 4, 1)

    df4 = df3[(start <= df3['売上伝票日付']) & (df3['売上伝票日付'] < end)]
    #df4 = df3[(start <= df3['売上伝票日付'] < end)]
    
    fig = plt.figure(figsize=(18,4))
    ax = fig.add_subplot(111)
    ax.set_title('金額')
    ax.set_xlim(start, end)
    ax.set_ylim(0, 120000)
    ax.plot(df4['売上伝票日付'], df4['金額'], c='b')
    ax.grid()
    plt.show()
    print(df4.sum())
# Out:
# 金額    3375115
# dtype: int64
# 金額    3289948
# dtype: int64
# 金額    1781312
# dtype: int64

# %%
year=2019
df3[(dt.datetime(year,2,1) <= df3['売上伝票日付']) & (df3['売上伝票日付'] < dt.datetime(year,3,1))]
# Out:
#         売上伝票日付     金額
# 590 2019-02-01  12419
# 591 2019-02-02  28922
# 592 2019-02-04  10856
# 593 2019-02-05  28199
# 594 2019-02-07  11180
# 595 2019-02-08  12335
# 596 2019-02-09  27887
# 597 2019-02-10  76403
# 598 2019-02-11  27896
# 599 2019-02-12  32493
# 600 2019-02-14  24614
# 601 2019-02-15   9847
# 602 2019-02-16  27510
# 603 2019-02-18  21184
# 604 2019-02-19  24745
# 605 2019-02-21  19455
# 606 2019-02-22  20595
# 607 2019-02-23  30940
# 608 2019-02-25  20508
# 609 2019-02-26  36817
# 610 2019-02-28  53071

# %%
d = dt.datetime(2019,2,10)

# %%
d
# Out:
# datetime.datetime(2019, 2, 10, 0, 0)

# %%
d??

# %%
d.weekday()
# Out:
# 6

# %%
dt.datetime(2020,2,13).weekday()
# Out:
# 3

# %%
dt.datetime(2022,1,10).weekday()
# Out:
# 0

# %%
dt.datetime(2022,1,10,12,0,0).weekday()
# Out:
# 0

# %%
df3[(dt.datetime(year,2,1) <= df3['売上伝票日付']) & (df3['売上伝票日付'] < dt.datetime(year,3,1))].plot.bar()
# Out:
# <AxesSubplot:>

# %%
for year in [2019, 2020, 2021]:
    start = dt.datetime(year-1, 12, 1)
    end = dt.datetime(year, 4, 1)

    df4 = df3[(start <= df3['売上伝票日付']) & (df3['売上伝票日付'] < end)]
    #df4 = df3[(start <= df3['売上伝票日付'] < end)]
    
    fig = plt.figure(figsize=(18,4))
    ax = fig.add_subplot(111)
    ax.set_title('金額')
    ax.set_xlim(start, end)
    ax.set_ylim(0, 120000)
    ax.bar(df4['売上伝票日付'], df4['金額'], color='b')
    ax.grid()
    plt.show()
    print(df4.sum())
# Out:
# 金額    2623115
# dtype: int64
# 金額    2590128
# dtype: int64
# 金額    1041763
# dtype: int64

# %%
df3
# Out:
#          売上伝票日付     金額
# 0    2017-03-01   8213
# 1    2017-03-02   4307
# 2    2017-03-03  19571
# 3    2017-03-04  14965
# 4    2017-03-05  17022
# ...         ...    ...
# 1111 2021-01-25  41993
# 1112 2021-01-26  24036
# 1113 2021-01-28  27323
# 1114 2021-01-29  17977
# 1115 2021-01-30  21659
#
# [1116 rows x 2 columns]

# %%
# Prophet by Facebook 
from prophet import Prophet

# %%
df5 = df3.copy()
df5['ds'] = df5['売上伝票日付']
df5['y'] = df5['金額']

mday = pd.to_datetime('2021-2-1')
train_index = df5['ds'] < mday
test_index = df5['ds'] >= mday

x = df5[['ds']]
x_train = df5[train_index]
x_test = df5[test_index]

y = df5['y']
y_train = df5['y'][train_index]
y_test = df5['y'][test_index]

dates_train = df5['ds'][train_index]
dates_test = df5['ds'][test_index]

# %%
x_train
# Out:
#          売上伝票日付     金額         ds      y
# 0    2017-03-01   8213 2017-03-01   8213
# 1    2017-03-02   4307 2017-03-02   4307
# 2    2017-03-03  19571 2017-03-03  19571
# 3    2017-03-04  14965 2017-03-04  14965
# 4    2017-03-05  17022 2017-03-05  17022
# ...         ...    ...        ...    ...
# 1111 2021-01-25  41993 2021-01-25  41993
# 1112 2021-01-26  24036 2021-01-26  24036
# 1113 2021-01-28  27323 2021-01-28  27323
# 1114 2021-01-29  17977 2021-01-29  17977
# 1115 2021-01-30  21659 2021-01-30  21659
#
# [1116 rows x 4 columns]

# %%
model = Prophet(yearly_seasonality=True, weekly_seasonality=True, daily_seasonality=False,
    changepoint_prior_scale=0.01, seasonality_mode='multiplicative')
#model.add_seasonality(name='1-period', period=150, fourier_order=5)
model.fit(x_train)

#future = df2[['ds']]
future = model.make_future_dataframe(periods=28)
forecast = model.predict(future)

fig1 = model.plot(forecast)
fig2 = model.plot_components(forecast)
# Out:
# Initial log joint probability = -8.61452
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       2148.47    0.00456201        420.29           1           1      121
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      189       2149.39   1.89688e-06        435.82   3.469e-09       0.001      282  LS failed, Hessian reset
#      199        2149.4   1.14521e-07       363.406           1           1      295
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      204        2149.4   9.99745e-09       422.897      0.1532      0.1532      301
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance

# %%
df5 = pd.DataFrame()

#years = [2017, 2018, 2019, 2020, 2021]
#years = [2019, 2020, 2021]
years = [2021]

for year in years:
#    start = dt.datetime(year, 1, 1)
#    end = dt.datetime(year+1, 1, 1)
    start = dt.datetime(year-1, 10, 1)
    end = dt.datetime(year, 3, 1)

    df4 = df3[(start <= df3['売上伝票日付']) & (df3['売上伝票日付'] < end)]
    df5 = df5.append(df4)

# %%
df5['ds'] = df5['売上伝票日付']
df5['y'] = df5['金額']

mday = pd.to_datetime('2021-2-1')
train_index = df5['ds'] < mday
test_index = df5['ds'] >= mday

x_train = df5[train_index]
x_test = df5[test_index]

y_train = df5['y'][train_index]
y_test = df5['y'][test_index]

dates_train = df5['ds'][train_index]
dates_test = df5['ds'][test_index]

# %%
from dateutil.relativedelta import relativedelta

# %%
relativedelta?

# %%
l = []
#for y in [2019, 2020, 2021]:
y = 2019
for i in range(790):
    d = dt.datetime(y, 1, 1) + relativedelta(days=i) 
    day = d.weekday()
    if day == 2 or day == 6:
        l.append(d)
    else:
        pass

# %%
l[-20:]
# Out:
# [datetime.datetime(2020, 12, 23, 0, 0),
#  datetime.datetime(2020, 12, 27, 0, 0),
#  datetime.datetime(2020, 12, 30, 0, 0),
#  datetime.datetime(2021, 1, 3, 0, 0),
#  datetime.datetime(2021, 1, 6, 0, 0),
#  datetime.datetime(2021, 1, 10, 0, 0),
#  datetime.datetime(2021, 1, 13, 0, 0),
#  datetime.datetime(2021, 1, 17, 0, 0),
#  datetime.datetime(2021, 1, 20, 0, 0),
#  datetime.datetime(2021, 1, 24, 0, 0),
#  datetime.datetime(2021, 1, 27, 0, 0),
#  datetime.datetime(2021, 1, 31, 0, 0),
#  datetime.datetime(2021, 2, 3, 0, 0),
#  datetime.datetime(2021, 2, 7, 0, 0),
#  datetime.datetime(2021, 2, 10, 0, 0),
#  datetime.datetime(2021, 2, 14, 0, 0),
#  datetime.datetime(2021, 2, 17, 0, 0),
#  datetime.datetime(2021, 2, 21, 0, 0),
#  datetime.datetime(2021, 2, 24, 0, 0),
#  datetime.datetime(2021, 2, 28, 0, 0)]

# %%
holidays = pd.DataFrame({
  'holiday': 'playoff',
  'ds': pd.to_datetime(l),
  'lower_window': 0,
  'upper_window': 1,
})

# %%
#model = Prophet(yearly_seasonality=False, weekly_seasonality=True, daily_seasonality=False,
#    changepoint_prior_scale=0.01, seasonality_mode='multiplicative')
#model = Prophet(yearly_seasonality=False, weekly_seasonality=True, daily_seasonality=False)
model = Prophet(yearly_seasonality=False, weekly_seasonality=True, daily_seasonality=False, holidays=holidays)
#model.add_seasonality(name='1-period', period=150, fourier_order=5)
#model.add_seasonality(name='monthly', period=30.5, fourier_order=5)
model.fit(x_train)

#future = df2[['ds']]
future = model.make_future_dataframe(periods=29)
forecast = model.predict(future)
# Out:
# Initial log joint probability = -54.4155
# Iteration  1. Log joint probability =    34.9367. Improved by 89.3521.
# Iteration  2. Log joint probability =    118.497. Improved by 83.5599.
# Iteration  3. Log joint probability =    130.757. Improved by 12.2609.
# Iteration  4. Log joint probability =    130.791. Improved by 0.0337829.
# Iteration  5. Log joint probability =    130.835. Improved by 0.0438587.
# Iteration  6. Log joint probability =    130.838. Improved by 0.00276833.
# Iteration  7. Log joint probability =    130.859. Improved by 0.0213723.
# Iteration  8. Log joint probability =    130.883. Improved by 0.0239433.
# Iteration  9. Log joint probability =    131.059. Improved by 0.17545.
# Iteration 10. Log joint probability =    131.122. Improved by 0.0634173.
# Iteration 11. Log joint probability =    131.142. Improved by 0.0197699.
# Iteration 12. Log joint probability =    131.228. Improved by 0.0867358.
# Iteration 13. Log joint probability =     131.44. Improved by 0.211152.
# Iteration 14. Log joint probability =    131.594. Improved by 0.153889.
# Iteration 15. Log joint probability =    131.607. Improved by 0.0139778.
# Iteration 16. Log joint probability =    131.879. Improved by 0.271315.
# Iteration 17. Log joint probability =     131.92. Improved by 0.0412497.
# Iteration 18. Log joint probability =    131.992. Improved by 0.0721369.
# Iteration 19. Log joint probability =    132.136. Improved by 0.144114.
# Iteration 20. Log joint probability =     132.16. Improved by 0.0236369.
# Iteration 21. Log joint probability =    132.184. Improved by 0.0239609.
# Iteration 22. Log joint probability =      132.2. Improved by 0.0157487.
# Iteration 23. Log joint probability =    132.229. Improved by 0.0293296.
# Iteration 24. Log joint probability =    132.239. Improved by 0.0100766.
# Iteration 25. Log joint probability =    132.271. Improved by 0.0324057.
# Iteration 26. Log joint probability =    132.277. Improved by 0.00544687.
# Iteration 27. Log joint probability =    132.313. Improved by 0.0357825.
# Iteration 28. Log joint probability =    132.314. Improved by 0.00159571.
# Iteration 29. Log joint probability =    132.351. Improved by 0.0370641.
# Iteration 30. Log joint probability =     132.42. Improved by 0.0686765.
# Iteration 31. Log joint probability =    133.428. Improved by 1.00824.
# Iteration 32. Log joint probability =    133.487. Improved by 0.0591149.
# Iteration 33. Log joint probability =    133.544. Improved by 0.056804.
# Iteration 34. Log joint probability =    133.573. Improved by 0.0287537.
# Iteration 35. Log joint probability =    133.591. Improved by 0.0184273.
# Iteration 36. Log joint probability =    133.602. Improved by 0.0107751.
# Iteration 37. Log joint probability =    133.611. Improved by 0.00910286.
# Iteration 38. Log joint probability =    133.617. Improved by 0.00581029.
# Iteration 39. Log joint probability =     133.62. Improved by 0.00262269.
# Iteration 40. Log joint probability =    133.621. Improved by 0.000965986.
# Iteration 41. Log joint probability =    133.621. Improved by 0.000666286.
# Iteration 42. Log joint probability =    133.622. Improved by 0.000481418.
# Iteration 43. Log joint probability =    133.622. Improved by 0.000380434.
# Iteration 44. Log joint probability =    133.622. Improved by 2.98265e-06.
# Iteration 45. Log joint probability =    133.622. Improved by 6.65639e-07.
# Iteration 46. Log joint probability =    133.622. Improved by 6.64166e-06.
# Iteration 47. Log joint probability =    133.622. Improved by 0.000183857.
# Iteration 48. Log joint probability =    133.622. Improved by 1.46896e-05.
# Iteration 49. Log joint probability =    133.622. Improved by 0.000114154.
# Iteration 50. Log joint probability =    133.623. Improved by 2.92487e-05.
# Iteration 51. Log joint probability =    133.623. Improved by 6.16973e-06.
# Iteration 52. Log joint probability =    133.623. Improved by 1.56907e-05.
# Iteration 53. Log joint probability =    133.623. Improved by 1.10469e-05.
# Iteration 54. Log joint probability =    133.623. Improved by 6.15791e-06.
# Iteration 55. Log joint probability =    133.623. Improved by 1.31151e-06.
# Iteration 56. Log joint probability =    133.623. Improved by 5.49111e-06.
# Iteration 57. Log joint probability =    133.623. Improved by 2.28591e-06.
# Iteration 58. Log joint probability =    133.623. Improved by 1.29999e-06.
# Iteration 59. Log joint probability =    133.623. Improved by 1.12702e-06.
# Iteration 60. Log joint probability =    133.623. Improved by 4.75467e-07.
# Iteration 61. Log joint probability =    133.623. Improved by 2.03391e-07.
# Iteration 62. Log joint probability =    133.623. Improved by 2.73315e-07.
# Iteration 63. Log joint probability =    133.623. Improved by 2.885e-08.
# Iteration 64. Log joint probability =    133.623. Improved by 1.45888e-07.
# Iteration 65. Log joint probability =    133.623. Improved by 6.6646e-08.
# Iteration 66. Log joint probability =    133.623. Improved by 7.96059e-08.
# Iteration 67. Log joint probability =    133.623. Improved by 3.17035e-08.
# Iteration 68. Log joint probability =    133.623. Improved by 8.27325e-09.

# %%
fig1 = model.plot(forecast)
fig2 = model.plot_components(forecast)

# %%
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail(28)
# Out:
#             ds        yhat  yhat_lower  yhat_upper
# 86  2021-02-01  26774.7018   8686.5360  44673.9256
# 87  2021-02-02  20647.6716   2295.5692  38663.8708
# 88  2021-02-03 -32992.2837 -50893.7428 -13712.2919
# 89  2021-02-04  25816.8235   8431.2985  44053.9104
# 90  2021-02-05  10250.3285  -6716.4592  27376.9100
# 91  2021-02-06  26185.5947   7584.7621  44327.2105
# 92  2021-02-07 -33513.9800 -51377.2179 -14707.4793
# 93  2021-02-08  25861.7268   7744.9718  43277.0725
# 94  2021-02-09  19734.6966   1695.4342  37444.6699
# 95  2021-02-10 -33905.2587 -51419.6033 -16844.4346
# 96  2021-02-11  24903.8485   7173.9212  42330.7122
# 97  2021-02-12   9337.3535  -7652.3260  26950.5368
# 98  2021-02-13  25272.6197   7512.6833  44113.8285
# 99  2021-02-14 -34426.9550 -52793.1161 -16335.4510
# 100 2021-02-15  24948.7518   7346.2571  43673.5886
# 101 2021-02-16  18821.7217   1517.8917  37415.0572
# 102 2021-02-17 -34818.2336 -54101.1156 -17226.4306
# 103 2021-02-18  23990.8735   6483.2372  42142.1728
# 104 2021-02-19   8424.3785 -10165.9390  27166.8058
# 105 2021-02-20  24359.6447   7235.0360  43091.0369
# 106 2021-02-21 -35339.9300 -53277.2554 -17372.4871
# 107 2021-02-22  24035.7769   6347.3106  42113.4739
# 108 2021-02-23  17908.7467    438.8831  34765.1280
# 109 2021-02-24 -35731.2086 -52398.3363 -17583.4766
# 110 2021-02-25  23077.8986   5487.9475  41771.0772
# 111 2021-02-26   7511.4036 -10640.7825  25654.7771
# 112 2021-02-27  23446.6698   5466.3885  40568.6383
# 113 2021-02-28 -36252.9049 -53340.5529 -18821.7373

# %%
fig1 = model.plot(forecast, figsize=(18,10))

# %%
fig2 = model.plot_components(forecast, figsize=(18,10))

# %%
df6 = forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail(28)

# %%
df6
# Out:
#             ds        yhat  yhat_lower  yhat_upper
# 86  2021-02-01  26774.7018   8686.5360  44673.9256
# 87  2021-02-02  20647.6716   2295.5692  38663.8708
# 88  2021-02-03 -32992.2837 -50893.7428 -13712.2919
# 89  2021-02-04  25816.8235   8431.2985  44053.9104
# 90  2021-02-05  10250.3285  -6716.4592  27376.9100
# 91  2021-02-06  26185.5947   7584.7621  44327.2105
# 92  2021-02-07 -33513.9800 -51377.2179 -14707.4793
# 93  2021-02-08  25861.7268   7744.9718  43277.0725
# 94  2021-02-09  19734.6966   1695.4342  37444.6699
# 95  2021-02-10 -33905.2587 -51419.6033 -16844.4346
# 96  2021-02-11  24903.8485   7173.9212  42330.7122
# 97  2021-02-12   9337.3535  -7652.3260  26950.5368
# 98  2021-02-13  25272.6197   7512.6833  44113.8285
# 99  2021-02-14 -34426.9550 -52793.1161 -16335.4510
# 100 2021-02-15  24948.7518   7346.2571  43673.5886
# 101 2021-02-16  18821.7217   1517.8917  37415.0572
# 102 2021-02-17 -34818.2336 -54101.1156 -17226.4306
# 103 2021-02-18  23990.8735   6483.2372  42142.1728
# 104 2021-02-19   8424.3785 -10165.9390  27166.8058
# 105 2021-02-20  24359.6447   7235.0360  43091.0369
# 106 2021-02-21 -35339.9300 -53277.2554 -17372.4871
# 107 2021-02-22  24035.7769   6347.3106  42113.4739
# 108 2021-02-23  17908.7467    438.8831  34765.1280
# 109 2021-02-24 -35731.2086 -52398.3363 -17583.4766
# 110 2021-02-25  23077.8986   5487.9475  41771.0772
# 111 2021-02-26   7511.4036 -10640.7825  25654.7771
# 112 2021-02-27  23446.6698   5466.3885  40568.6383
# 113 2021-02-28 -36252.9049 -53340.5529 -18821.7373

# %%
df6['Id'] = df6['ds'].apply(lambda x: x.strftime('%Y/%-m/%-d'))
df6['Expected'] = df6['yhat'].astype('int')
df6
# Out:
#             ds        yhat  yhat_lower  yhat_upper         Id  Expected
# 86  2021-02-01  26774.7018   8686.5360  44673.9256   2021/2/1     26774
# 87  2021-02-02  20647.6716   2295.5692  38663.8708   2021/2/2     20647
# 88  2021-02-03 -32992.2837 -50893.7428 -13712.2919   2021/2/3    -32992
# 89  2021-02-04  25816.8235   8431.2985  44053.9104   2021/2/4     25816
# 90  2021-02-05  10250.3285  -6716.4592  27376.9100   2021/2/5     10250
# 91  2021-02-06  26185.5947   7584.7621  44327.2105   2021/2/6     26185
# 92  2021-02-07 -33513.9800 -51377.2179 -14707.4793   2021/2/7    -33513
# 93  2021-02-08  25861.7268   7744.9718  43277.0725   2021/2/8     25861
# 94  2021-02-09  19734.6966   1695.4342  37444.6699   2021/2/9     19734
# 95  2021-02-10 -33905.2587 -51419.6033 -16844.4346  2021/2/10    -33905
# 96  2021-02-11  24903.8485   7173.9212  42330.7122  2021/2/11     24903
# 97  2021-02-12   9337.3535  -7652.3260  26950.5368  2021/2/12      9337
# 98  2021-02-13  25272.6197   7512.6833  44113.8285  2021/2/13     25272
# 99  2021-02-14 -34426.9550 -52793.1161 -16335.4510  2021/2/14    -34426
# 100 2021-02-15  24948.7518   7346.2571  43673.5886  2021/2/15     24948
# 101 2021-02-16  18821.7217   1517.8917  37415.0572  2021/2/16     18821
# 102 2021-02-17 -34818.2336 -54101.1156 -17226.4306  2021/2/17    -34818
# 103 2021-02-18  23990.8735   6483.2372  42142.1728  2021/2/18     23990
# 104 2021-02-19   8424.3785 -10165.9390  27166.8058  2021/2/19      8424
# 105 2021-02-20  24359.6447   7235.0360  43091.0369  2021/2/20     24359
# 106 2021-02-21 -35339.9300 -53277.2554 -17372.4871  2021/2/21    -35339
# 107 2021-02-22  24035.7769   6347.3106  42113.4739  2021/2/22     24035
# 108 2021-02-23  17908.7467    438.8831  34765.1280  2021/2/23     17908
# 109 2021-02-24 -35731.2086 -52398.3363 -17583.4766  2021/2/24    -35731
# 110 2021-02-25  23077.8986   5487.9475  41771.0772  2021/2/25     23077
# 111 2021-02-26   7511.4036 -10640.7825  25654.7771  2021/2/26      7511
# 112 2021-02-27  23446.6698   5466.3885  40568.6383  2021/2/27     23446
# 113 2021-02-28 -36252.9049 -53340.5529 -18821.7373  2021/2/28    -36252

# %%
# df7 = df6[df6.yhat > 0].rename(columns={'ds':'Id', 'yhat':'Expected'}).drop(columns=['yhat_lower', 'yhat_upper'])
df7 = df6[df6.yhat > 0].drop(columns=['ds', 'yhat', 'yhat_lower', 'yhat_upper'])

# %%
df7
# Out:
#             Id  Expected
# 86    2021/2/1     26774
# 87    2021/2/2     20647
# 89    2021/2/4     25816
# 90    2021/2/5     10250
# 91    2021/2/6     26185
# 93    2021/2/8     25861
# 94    2021/2/9     19734
# 96   2021/2/11     24903
# 97   2021/2/12      9337
# 98   2021/2/13     25272
# 100  2021/2/15     24948
# 101  2021/2/16     18821
# 103  2021/2/18     23990
# 104  2021/2/19      8424
# 105  2021/2/20     24359
# 107  2021/2/22     24035
# 108  2021/2/23     17908
# 110  2021/2/25     23077
# 111  2021/2/26      7511
# 112  2021/2/27     23446

# %%
df7.to_csv('../output/submission.csv', index=False)
